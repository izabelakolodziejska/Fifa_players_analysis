# %% [markdown]
# ## Analiza piłkarzy na podstawie danych z gry Fifa
# - Oktawian Kausz
# - Izabela Kołodziejska 217260
# - Piotr Kula
# - Kamil Marszałek

# %% [markdown]
# tu będzie streszczenie

# %% [markdown]
# ### słowa kluczowe być może się tu pojawią

# %% [markdown]
# WPROWADZENIE: Przedmiotem naszej analizy opierającej się na porządkowaniu obiektów są piłkarze z całego świata. (tu pewno opis tych rankingów, bla bla) Wykorzystaliśmy zbiór danych pochodzących z gry FIFA 24, ponieważ zawiera ona szczegółowe informacje dotyczące rzeczywistych zawodników.

# %% [markdown]
# na razie chamski przekop z opisu:
#         • Przedmiot badania
#         ◦ Cel i zakres badania
#         ◦ Przegląd literatury (min. 1 cytowanie powiązane tematycznie i krótki opis co było badane) TRZEBA BYŁO WZIĄĆ JABŁKA
#         ◦ Zmienne wybrane do analizy (opis i uzasadnienie zmiennych oraz podział na stymulanty/destymulanty) – minimum sześć zmiennych
#         ◦ Wstępna analiza danych
#             ▪ statystyki opisowe (przynajmniej: średnia, mediana, minimum, maksimum, odchylenie standardowe, skośność)
#             ▪ podstawowa wizualizacja – np. boxplot, histogramy
#             ▪ braki danych – czy występują i jak je obsłużono
#             ▪ obserwacje odstające i w jaki sposób je obsłużono
#     • Opis metod
#         ◦ wzory wraz z opisami oznaczeń
#         ◦ cytowanie pracy w której zaproponowano metodę/ewentualnie pracy, w której użyto metodę)
#     • Rezultaty (w postaci tabelarycznej i/lub graficznej oraz omówienie wyników)
#     • Podsumowanie (ocena realizacji celu, odniesienie do pozycji z przeglądu literatury)
#     • Bibliografia
# W przypadku porządkowania obiektów stworzenie minimum trzech rankingów (np. z różnych metod normalizacji, różnych metod porządkowania)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
 
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
seed = 2024

# %%
data = pd.read_excel('FIFA_MAD_dane.xlsx')
data.head()
# Out:
#                      player   country  height  age            club  dribbling  \
# 0  Cristian Castro Devenish  Colombia     192   22  Atl. Nacional          43
# 1          Silaldo Taffarel    Brazil     181   31    Corinthians          70
# 2              Thomas Dähne   Germany     193   29  Holstein Kiel          12
# 3         Michael Sollbauer   Austria     187   33  SK Rapid Wien          48
# 4             Diego Segovia   Uruguay     191   23  Independiente           8
#
#    reactions  interceptions  vision  stamina  strength  balance  sprint_speed  \
# 0         68             65      30       55        86       40            52
# 1         70             70      64       87        81       42            67
# 2         65             20      49       38        68       41            48
# 3         64             66      29       73        82       56            63
# 4         50             12      38       28        64       24            31
#
#    agility  ball_uncontrol  instability
# 0       43              45           50
# 1       65              31           46
# 2       36              75           52
# 3       57              54           30
# 4       34              86           66

# %%
values = pd.read_excel('FIFA_MAD_dane.xlsx', sheet_name='wartosci')
values.head()
# Out:
#                Unnamed: 0  dribbling  reactions  interceptions     vision  \
# 0                 Średnia  56.128476  61.959345      47.389124  54.465681
# 1  Odchylenie standardowe  18.770423   8.892526      20.449527  13.704080
# 2                 Mediana  62.000000  62.000000      54.000000  56.000000
# 3             Kwartyl 25%  51.000000  56.000000      28.000000  45.000000
# 4              Kwatyl 50%  62.000000  62.000000      54.000000  56.000000
#
#      stamina   strength    balance  sprint_speed    agility  ball_uncontrol  \
# 0  63.377332  65.381204  64.070398     64.958993  63.780535       41.087821
# 1  16.104480  12.622942  14.494169     15.112714  14.856567       16.565610
# 2  66.000000  66.500000  66.000000     68.000000  66.000000       37.000000
# 3  56.000000  58.000000  56.000000     57.000000  56.000000       31.000000
# 4  66.000000  66.500000  66.000000     68.000000  66.000000       37.000000
#
#    instability
# 0    41.379092
# 1    12.023044
# 2    40.000000
# 3    33.000000
# 4    40.000000

# %% [markdown]
# Standaryzacja danych do użycia w analizie składowych głównych (PCA)

# %%
data_with_numbers = data.drop(['player', 'country', 'club'], axis=1)
scaler = StandardScaler()
df = scaler.fit_transform(data_with_numbers)

# %% [markdown]
# wykonanie PCA

# %%
pca = PCA(n_components=3)
pca.fit(df)
# Out:
# PCA(n_components=3)

# %% [markdown]
# ## Interpretacja wyników: które cechy mają największy wpływ na róznice między piłkarzami.
# Wykorzystywana jest analiza współczynników ładunku głównych składowych PC. Wartości te określają jak bardzo każda cecha przyczynia się do każdej głównej składowej.
# - Wartości bliskie zeru wskazują na to, że dana cecha ma mały wpływ na dany komponent główny.
# - Dodatnie wartości wskazują na pozytywną korelację między daną cechą a danym komponentem głównym, podczas gdy ujemne wartości wskazują na negatywną korelację.
# - Im większa wartość bezwzględna, tym większy wpływ ma dana cecha na dany komponent główny.

# %%
loadings = pca.components_
loadings_df = pd.DataFrame(loadings, columns=data_with_numbers.columns)
print(loadings_df)
# Out:
#      height       age  dribbling  reactions  interceptions    vision  \
# 0  0.222991 -0.057384  -0.368559  -0.213211      -0.191200 -0.305085
# 1 -0.395746 -0.372543   0.034999  -0.353167      -0.244536 -0.047134
# 2 -0.153838  0.471962  -0.045975   0.318997      -0.446718  0.367646
#
#     stamina  strength   balance  sprint_speed   agility  ball_uncontrol  \
# 0 -0.318188 -0.016123 -0.310811     -0.303953 -0.336407        0.367607
# 1 -0.129069 -0.529605  0.283719      0.151772  0.214707        0.053130
# 2 -0.346884 -0.289976  0.046299     -0.255044  0.037640        0.086119
#
#    instability
# 0     0.311855
# 1     0.258904
# 2    -0.185884

# %% [markdown]
# ## Wnioski
# - pierwsza główna składowa (indeks 0): największy wpływ na tę składową mają zmienne <b>dribbling, vision, stamina, balance, sprint_speed, agility</b>. Wszystkie te zmienne mają ujemne ładunki, co oznacza, że im wyższa jest wartość tych zmiennych, tym niższa jest wartość tej głównej składowej. Zmienne <b>height, ball_uncontrol i instability</b> mają dodatni ładunek, co oznacza, że im wyższa jest wartość tych zmiennych, tym wyższa jest wartość tej głównej składowej.
# - druga główna składowa (indeks 1) : zmienne ujemne o największym wpływie: <b>height, age, reactions, strength</b> zmienne dodatnie: <b>balance i instability</b>
# - trzecia główna składowa (indeks 2): ujemne zmienne: <b>interceptions, stamina, strength</b> dodatnie zmienne: <b>age, reactions, vision</b>
# ### Ogólnie wynika, że cechy takie jak vision, stamina, height, age, reactions oraz strength najbardziej wpływają na różnice między piłkarzami.

# %%
pca_data = pca.transform(df)
plt.scatter(pca_data[:,0], pca_data[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA')
plt.show()

# %% [markdown]
# możliwe że ta sekcja pca jest do wywalenia, to chat zaproponował

# %% [markdown]
# Metoda TOPSIS

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])  
scaled_numeric_data = scaler.fit_transform(numeric_data) 
scaled_numeric_data
# Out:
# array([[ 1.51266818, -0.91261559, -0.69942353, ..., -1.39874406,
#          0.23616268,  0.71703209],
#        [-0.09819508,  0.99031351,  0.73900965, ...,  0.08208255,
#         -0.60896166,  0.38433763],
#        [ 1.65911029,  0.56744038, -2.35095794, ..., -1.86991617,
#          2.04714341,  0.88337932],
#        ...,
#        [-0.97684777,  0.99031351,  2.07089224, ...,  1.96677097,
#         -2.11811227, -2.85943334],
#        [ 0.7804576 ,  2.47036948,  1.32503799, ...,  0.88980616,
#         -1.6955501 , -2.94260695],
#        [ 1.95199452,  3.10467918,  1.00538617, ...,  0.21670316,
#         -1.57481805, -2.60991249]])

# %% [markdown]
# height       age  dribbling  reactions  interceptions    vision stamina  strength   balance  sprint_speed   agility  ball_uncontrol instability
# wagi przypisane z analizy pca

# %%
weights = [0.11428571, 0.11428571, 0.02857143, 0.14285714, 0.02857143, 0.14285714, 0.05714286, 0.14285714, 0.08571429, 0.05714286, 0.02857143, 0.02857143,
 0.02857143]

# %% [markdown]
# idealne i nieidealne rozwiązanie

# %%
ideal_solution = np.max(scaled_numeric_data, axis=0)
non_ideal_solution = np.min(scaled_numeric_data, axis=0)

# %% [markdown]
# Obliczenie odległości od idealnego oraz nieidealnego rozwiązania

# %%
distance_to_ideal = np.sqrt(np.sum((scaled_numeric_data - ideal_solution) ** 2, axis=1))
distance_to_non_ideal = np.sqrt(np.sum((scaled_numeric_data - non_ideal_solution) ** 2, axis=1))

# %% [markdown]
# Obliczenie wyniku TOPSIS

# %%
topsis_score = distance_to_non_ideal / (distance_to_ideal + distance_to_non_ideal)

# %% [markdown]
# Dodanie kolumny z wynikiem TOPSIS do danych i sortowanie

# %%
data['TOPSIS Score'] = topsis_score
sorted_data = data.sort_values(by='TOPSIS Score', ascending=False)
print(sorted_data)
sorted_data.to_excel("posortowane_wedlug_topsis.xlsx", index=False)
# Out:
#                    player  country  height  age                club  \
# 1374       Luis Advíncula     Peru     180   33       Boca Juniors
# 3844             Emre Can  Germany     186   29  Borussia Dortmund
# 3643      Guilherme Sityá   Brazil     180   33          Konyaspor
# 797           Fredditinho   Brazil     188   35          Palmeiras
# 4108  Giovanni Di Lorenzo    Italy     183   30          Napoli FC
# ...                   ...      ...     ...  ...                 ...
# 1764      Alan Madaliński   Poland     186   18      Miedź Legnica
# 2041   Magnus Rugland Ree   Norway     182   19          Viking FK
# 850         Edoardo Sarri    Italy     187   24               Bari
# 1402  Lalthuammawia Ralte    India     176   30          Odisha FC
# 2920      Paul Tschernuth  Austria     186   21         Heidenheim
#
#       dribbling  reactions  interceptions  vision  stamina  strength  balance  \
# 1374         74         70             71      65       88        79       80
# 3844         81         81             81      76       86        86       75
# 3643         72         69             68      68       86        78       75
# 797          72         74             45      65       65        90       80
# 4108         76         80             79      66       90        76       78
# ...         ...        ...            ...     ...      ...       ...      ...
# 1764          5         38              9      27       28        53       34
# 2041         11         47              9      28       22        47       49
# 850           7         37             14      35       16        46       32
# 1402         13         42              6      34       21        35       48
# 2920         12         41              7      21       24        41       38
#
#       sprint_speed  agility  ball_uncontrol  instability  TOPSIS Score
# 1374            88       82              28           40      0.636252
# 3844            88       72              22           20      0.629485
# 3643            82       79              30           35      0.619379
# 797             73       82              26           28      0.618117
# 4108            85       78              23           23      0.617798
# ...            ...      ...             ...          ...           ...
# 1764            21       33              82           64      0.366783
# 2041            16       23              86           61      0.365499
# 850             24       21              81           61      0.364891
# 1402            26       30              81           61      0.364859
# 2920            17       22              80           70      0.364187
#
# [5682 rows x 17 columns]
